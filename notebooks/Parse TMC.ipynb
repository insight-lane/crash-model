# %%
import xlrd
import pandas as pd
from os import listdir
from os import path

# %%
def file_dataframe(excel_sheet, data_location):
    column_time = data_location['columns'][0]
    column_east = column_time + 1
    column_south = column_time + 2
    column_west = column_time + 3
    column_north = column_time + 4
    
    start_r = data_location['rows'][0] + 3
    end_r = data_location['rows'][1]
    
    times = excel_sheet.col_values(column_time,start_r,end_r)
    times_strip = [x.strip() for x in times]
    east = excel_sheet.col_values(column_east,start_r,end_r)
    south = excel_sheet.col_values(column_south,start_r,end_r)
    west = excel_sheet.col_values(column_west,start_r,end_r)
    north = excel_sheet.col_values(column_north,start_r,end_r)

    columns = ['times', 'east', 'south', 'west', 'north']
    return(pd.DataFrame({'times':times_strip, 'east':east, 'south':south, 'west':west, 'north':north}, columns=columns))

# %%
# finding date
def find_date(excel_sheet):
    sheet_c = excel_sheet.ncols
    sheet_r = excel_sheet.nrows
    date = ''
    for col in range(sheet_c):
        for row in range(sheet_r):
            cell_value = excel_sheet.cell_value(rowx=row, colx=col)
            if "date" in str(cell_value).lower():
                date = cell_value
    return date

# %%
def data_location(excel_sheet):
    sheet_c = excel_sheet.ncols
    sheet_r = excel_sheet.nrows
    start_c = 0
    start_r = 0
    end_c = sheet_c - 2
    end_r = sheet_r - 2
    for col in range(sheet_c):
        for row in range(sheet_r):
            cell_value = excel_sheet.cell_value(rowx=row, colx=col)
            if "time" in str(cell_value).lower():
                start_c = col
                start_r = row
    return pd.DataFrame.from_records([('start', start_c, start_r), ('end', end_c, end_r)], columns=['value', 'columns', 'rows'])

# %%
def find_address(excel_sheet):
    return excel_sheet.cell_value(rowx=0, colx=0)

# %%
data_directory = '../data/raw/TURNING MOVEMENT COUNT/'
data_file_names = listdir(data_directory)

# %%
def extract_data_sheet(sheet, sheet_name, sheet_data_location, counter):
    sheet_df = file_dataframe(sheet, sheet_data_location)
    sheet_df['data_id'] = counter
    return(sheet_df)

# %%
def log_data_sheet(sheet, sheet_name, sheet_data_location, counter, file_name):
    global data_info
    address = find_address(sheet)
    date = find_date(sheet)
    
    column_time = sheet_data_location['columns'][0]
    row_time = sheet_data_location['rows'][0]
    
    row_street = row_time + 1
    column_east = column_time + 1
    column_south = column_time + 2
    column_west = column_time + 3
    column_north = column_time + 4
    
    east = sheet.cell_value(row_street, column_east)
    south = sheet.cell_value(row_street, column_south)
    west = sheet.cell_value(row_street, column_west)
    north = sheet.cell_value(row_street, column_north)
    
    record = pd.DataFrame([(counter, address, date, east, south, west, north, sheet_name, file_name)], 
                          columns=['id','address','date','east','south','west','north','data_type','filename'])
    data_info = data_info.append(record)

# %%
def extract_and_log_data_sheet(workbook, sheet_name, counter, file_name):
    sheet_index = sheet_names.index(sheet_name)
    sheet = workbook.sheet_by_index(sheet_index)
    sheet_data_location = data_location(sheet)
    
    data_sheet = extract_data_sheet(sheet, sheet_name, sheet_data_location, counter)
    log_data_sheet(sheet, sheet_name, sheet_data_location, counter, file_name)
    
    return(data_sheet)

# %%
all_data = pd.DataFrame()
data_info = pd.DataFrame(columns=['id','address','date','east','south','west','north','data_type', 'filename'])

i = 0

for file_name in data_file_names:   
    if file_name.endswith('.XLS'):
        file_path = path.join(data_directory, file_name)
        workbook = xlrd.open_workbook(file_path)
        sheet_names = [x.lower() for x in workbook.sheet_names()]

        if 'all motors' in sheet_names:
            i = i + 1
            motor = extract_and_log_data_sheet(workbook, 'all motors', i, file_name)
            all_data = all_data.append(motor)
            
        if 'all peds hr.' in sheet_names:
            i = i + 1
            pedestrian = extract_and_log_data_sheet(workbook, 'all peds hr.', i, file_name)
            all_data = all_data.append(pedestrian)
        
        if 'bicycles hr.' in sheet_names:
            i = i + 1
            pedestrian = extract_and_log_data_sheet(workbook, 'bicycles hr.', i, file_name)
            all_data = all_data.append(pedestrian)

all_data.reset_index(drop=True, inplace=True)    
data_info.reset_index(drop=True, inplace=True)

all_data = all_data.apply(pd.to_numeric, errors='ignore')
data_info = data_info.apply(pd.to_numeric, errors='ignore')

all_data.to_csv(path_or_buf=data_directory + 'all_data.csv', index=False)
data_info.to_csv(path_or_buf=data_directory + 'data_info.csv', index=False)

# %%
data_info
# Out:
#       id                                          address  \
# 0      1  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 1      2  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 2      3  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 3      4  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 4      5  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 5      6  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 6      7  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 7      8  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 8      9  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 9     10  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 10    11  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 11    12  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 12    13  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 13    14  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 14    15  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 15    16
# 16    17  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 17    18  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 18    19  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 19    20  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 20    21  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 21    22  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 22    23  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 23    24  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 24    25  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 25    26  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 26    27  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 27    28  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 28    29  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 29    30  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# ..   ...                                              ...
# 366  367  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 367  368  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 368  369  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 369  370  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 370  371  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 371  372  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 372  373  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 373  374  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 374  375  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 375  376  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 376  377  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 377  378  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 378  379  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 379  380  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 380  381  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 381  382  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 382  383  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 383  384  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 384  385  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 385  386  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 386  387  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 387  388  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 388  389  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 389  390  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 390  391  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 391  392  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 392  393  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 393  394  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 394  395  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
# 395  396  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500
#
#                     date             east             south             west  \
# 0         Date - 9.18.14  Bunker Hill St.       Mystic St.   Bunker Hill St.
# 1         Date - 9.18.14  Bunker Hill St.       Mystic St.   Bunker Hill St.
# 2         Date - 9.18.14  Bunker Hill St.       Mystic St.   Bunker Hill St.
# 3          Date - 4.9.14   No. Beacon St.     Cambridge St.    Brighton Ave.
# 4          Date - 4.9.14   No. Beacon St.     Cambridge St.    Brighton Ave.
# 5          Date - 4.9.14   No. Beacon St.     Cambridge St.    Brighton Ave.
# 6         Date - 1.21.15   West First St.        Pappas Way    East First St
# 7         Date - 1.21.15   West First St.        Pappas Way    East First St
# 8         Date - 1.21.15   West First St.        Pappas Way    East First St
# 9    Date - Nov. 16 2016                     Hyde Park Ave.    Neponset Ave.
# 10   Date - Nov. 16 2016                     Hyde Park Ave.    Neponset Ave.
# 11   Date - Nov. 16 2016                     Hyde Park Ave.    Neponset Ave.
# 12        Date - 7.8.14          Dana Ave    Hyde Park Ave.        Dana Ave.
# 13        Date - 7.8.14          Dana Ave    Hyde Park Ave.        Dana Ave.
# 14        Date - 7.8.14          Dana Ave    Hyde Park Ave.        Dana Ave.
# 15        Date - 12.1.15        Cedar St.        Centre St.        Cedar St.
# 16        Date - 12.1.15        Cedar St.        Centre St.        Cedar St.
# 17        Date - 12.1.15        Cedar St.        Centre St.        Cedar St.
# 18        Date - 4.30.14      Geneva Ave.      Normandy St.      Geneva Ave.
# 19        Date - 4.30.14           Bremen          Prescott           Bremen
# 20        Date - 4.30.14      Geneva Ave.      Normandy St.      Geneva Ave.
# 21        Date - 11.7.13       Dudley St.         Adams St.      Dudley St.
# 22        Date - 11.7.13       Dudley St.         Adams St.      Dudley St.
# 23        Date - 9.16.14  Southampton St.        Topeka St.  Southampton St.
# 24        Date - 9.16.14  Southampton St.        Topeka St.  Southampton St.
# 25        Date - 9.16.14  Southampton St.        Topeka St.  Southampton St.
# 26        Date - 5-15-14    Columbus Ave.     Dartmouth St.    Columbus Ave.
# 27        Date - 5-15-14    Columbus Ave.     Dartmouth St.    Columbus Ave.
# 28        Date - 5-15-14    Columbus Ave.     Dartmouth St.    Columbus Ave.
# 29                  Date      Talbot Ave.      NightingleSt       Talbot Ave
# ..                   ...              ...               ...              ...
# 366              Date -          A.L.Hwy.                           A.L.Hwy.
# 367              Date -          A.L.Hwy.                           A.L.Hwy.
# 368        Date -11-7-13       Bremen St.         Gove St.        Bremen St.
# 369        Date -11-7-13       Bremen St.         Gove St.        Bremen St.
# 370      Date - 11/16/16                     Hyde Park Ave.      Florian St.
# 371      Date - 11/16/16                     Hyde Park Ave.      Florian St.
# 372      Date - 11/16/16                     Hyde Park Ave.      Florian St.
# 373       Date  10-29-13      Schyler St.    Blue Hill Ave.   Castlegate St.
# 374       Date  10-29-13      Schyler St.    Blue Hill Ave.   Castlegate St.
# 375               Date -      W. Broadway             B St.      W. Broadway
# 376               Date -      W. Broadway             B St.      W. Broadway
# 377               Date -      W. Broadway             B St.      W. Broadway
# 378               Date -       Robert St.    So. Conway St.       Robert St.
# 379               Date -       Robert St.    So. Conway St.       Robert St.
# 380               Date -       Robert St.    So. Conway St.       Robert St.
# 381  Date - Oct. 4 2016        Robert St.  So. Fairview St.       Robert St.
# 382  Date - Oct. 4 2016        Robert St.  So. Fairview St.       Robert St.
# 383  Date - Oct. 4 2016        Robert St.  So. Fairview St.       Robert St.
# 384        Date -11.6.14                    Dorchester Ave.            D St.
# 385        Date -11.6.14                    Dorchester Ave.            D St.
# 386        Date -11.6.14                    Dorchester Ave.            D St.
# 387  Date - Sept 22 2016      Howland St.     Elm Hill Ave.      Howland St.
# 388  Date - Sept 22 2016      Howland St.     Elm Hill Ave.      Howland St.
# 389  Date - Sept 22 2016      Howland St.     Elm Hill Ave.      Howland St.
# 390       Date - 6.11.14   Dorchester St.    Old Colony Ave   Dorchester St.
# 391       Date - 6.11.14   Dorchester St.        Old Colony   Dorchester St.
# 392       Date - 6.11.14   Dorchester St.    Old Colony Ave   Dorchester St.
# 393       Date - 9.22.16        River St.       Webster St.        River St.
# 394       Date - 9.22.16        River St.       Webster St.        River St.
# 395       Date - 9.22.16        River St.       Webster St.        River St.
#
#                 north     data_type  \
# 0          School St.    all motors
# 1          School St.  all peds hr.
# 2          School St.  bicycles hr.
# 3       Cambridge St.    all motors
# 4       Cambridge St.  all peds hr.
# 5       Cambridge St.  bicycles hr.
# 6      West First St.    all motors
# 7      West First St.  all peds hr.
# 8      West First St.  bicycles hr.
# 9      Hyde Park Ave.    all motors
# 10     Hyde Park Ave.  all peds hr.
# 11     Hyde Park Ave.  bicycles hr.
# 12     Hyde Park Ave.    all motors
# 13     Hyde Park Ave.  all peds hr.
# 14     Hyde Park Ave.  bicycles hr.
# 15         Centre St.    all motors
# 16         Centre St.  all peds hr.
# 17         Centre St.  bicycles hr.
# 18                       all motors
# 19                     all peds hr.
# 20                     bicycles hr.
# 21          Adams St.  all peds hr.
# 22          Adams St.  bicycles hr.
# 23    Theo. Glynn Way    all motors
# 24    Theo. Glynn Way  all peds hr.
# 25    Theo. Glynn Way  bicycles hr.
# 26      Dartmouth St.    all motors
# 27      Dartmouth St.  all peds hr.
# 28      Dartmouth St.  bicycles hr.
# 29                     all peds hr.
# ..                ...           ...
# 366     #684 Entrance  all peds hr.
# 367     #684 Entrance  bicycles hr.
# 368                    all peds hr.
# 369                    bicycles hr.
# 370    Hyde Park Ave.    all motors
# 371    Hyde Park Ave.  all peds hr.
# 372    Hyde Park Ave.  bicycles hr.
# 373    Blue Hill Ave.  all peds hr.
# 374    Blue Hill Ave.  bicycles hr.
# 375             B St.    all motors
# 376             B St.  all peds hr.
# 377             B St.  bicycles hr.
# 378  So. Fairview St.    all motors
# 379  So. Fairview St.  all peds hr.
# 380  So. Fairview St.  bicycles hr.
# 381                      all motors
# 382                    all peds hr.
# 383                    bicycles hr.
# 384   Dorchester Ave.    all motors
# 385   Dorchester Ave.  all peds hr.
# 386   Dorchester Ave.  bicycles hr.
# 387     Elm Hill Ave.    all motors
# 388     Elm Hill Ave.  all peds hr.
# 389     Elm Hill Ave.  bicycles hr.
# 390    Old Colony Ave    all motors
# 391        Old Colony  all peds hr.
# 392    Old Colony Ave  bicycles hr.
# 393        Walter St.    all motors
# 394        Walter St.  all peds hr.
# 395        Walter St.  bicycles hr.
#
#                                               filename
# 0    7436_2407_BUNKER-HILL-ST,-MYSTIC-ST,-SCHOOL-ST...
# 1    7436_2407_BUNKER-HILL-ST,-MYSTIC-ST,-SCHOOL-ST...
# 2    7436_2407_BUNKER-HILL-ST,-MYSTIC-ST,-SCHOOL-ST...
# 3    6817_186_BRIGHTON-AVE,-CAMBRIDGE-ST,-NORTH-BEA...
# 4    6817_186_BRIGHTON-AVE,-CAMBRIDGE-ST,-NORTH-BEA...
# 5    6817_186_BRIGHTON-AVE,-CAMBRIDGE-ST,-NORTH-BEA...
# 6    7637_2101_EAST-FIRST-ST,-PAPPAS-WAY,-WEST-FIRS...
# 7    7637_2101_EAST-FIRST-ST,-PAPPAS-WAY,-WEST-FIRS...
# 8    7637_2101_EAST-FIRST-ST,-PAPPAS-WAY,-WEST-FIRS...
# 9    8469_883_HYDE-PARK-AVE,-NEPONSET-AVE_NA_NA_WES...
# 10   8469_883_HYDE-PARK-AVE,-NEPONSET-AVE_NA_NA_WES...
# 11   8469_883_HYDE-PARK-AVE,-NEPONSET-AVE_NA_NA_WES...
# 12   7298_1253_DANA-AVE,-HYDE-PARK-AVE_NA_NA_HYDE-P...
# 13   7298_1253_DANA-AVE,-HYDE-PARK-AVE_NA_NA_HYDE-P...
# 14   7298_1253_DANA-AVE,-HYDE-PARK-AVE_NA_NA_HYDE-P...
# 15   7925_1017_CEDAR-ST,-CENTRE-ST,-FORT-AVE_NA_NA_...
# 16   7925_1017_CEDAR-ST,-CENTRE-ST,-FORT-AVE_NA_NA_...
# 17   7925_1017_CEDAR-ST,-CENTRE-ST,-FORT-AVE_NA_NA_...
# 18   6846_2370_GENEVA-AVE,-NORMANDY-ST_NA_NA_DORCHE...
# 19   6846_2370_GENEVA-AVE,-NORMANDY-ST_NA_NA_DORCHE...
# 20   6846_2370_GENEVA-AVE,-NORMANDY-ST_NA_NA_DORCHE...
# 21   7281_2401_ADAMS-ST,-DUDLEY-ST_NA_NA_ROXBURY_11...
# 22   7281_2401_ADAMS-ST,-DUDLEY-ST_NA_NA_ROXBURY_11...
# 23   7435_891_SOUTHAMPTON-ST,-THEODORE-GLYNN-WAY,-T...
# 24   7435_891_SOUTHAMPTON-ST,-THEODORE-GLYNN-WAY,-T...
# 25   7435_891_SOUTHAMPTON-ST,-THEODORE-GLYNN-WAY,-T...
# 26   7269_319_COLUMBUS-AVE,-DARTMOUTH-ST_NA_NA_BOST...
# 27   7269_319_COLUMBUS-AVE,-DARTMOUTH-ST_NA_NA_BOST...
# 28   7269_319_COLUMBUS-AVE,-DARTMOUTH-ST_NA_NA_BOST...
# 29   6826_3144_NIGHTINGALE-ST,-TALBOT-AVE_NA_NA_DOR...
# ..                                                 ...
# 366  7376_2406_AMERICAN-LEGION-HWY,-#684_NA_NA_WEST...
# 367  7376_2406_AMERICAN-LEGION-HWY,-#684_NA_NA_WEST...
# 368  6879_1615_BREMEN-ST,-GOVE-ST_NA_NA_EAST-BOSTON...
# 369  6879_1615_BREMEN-ST,-GOVE-ST_NA_NA_EAST-BOSTON...
# 370  8472_2555_FLORIAN-ST,-HYDE-PARK-AVE_NA_NA_WEST...
# 371  8472_2555_FLORIAN-ST,-HYDE-PARK-AVE_NA_NA_WEST...
# 372  8472_2555_FLORIAN-ST,-HYDE-PARK-AVE_NA_NA_WEST...
# 373  6853_2175_BLUE-HILL-AVE,-CASTLEGATE-RD_NA_NA_R...
# 374  6853_2175_BLUE-HILL-AVE,-CASTLEGATE-RD_NA_NA_R...
# 375  8411_1387_B-ST,-WEST-BROADWAY_NA_NA_SOUTH-BOST...
# 376  8411_1387_B-ST,-WEST-BROADWAY_NA_NA_SOUTH-BOST...
# 377  8411_1387_B-ST,-WEST-BROADWAY_NA_NA_SOUTH-BOST...
# 378  8422_3150_ROBERT-ST,-SOUTH-CONWAY-ST_NA_NA_WES...
# 379  8422_3150_ROBERT-ST,-SOUTH-CONWAY-ST_NA_NA_WES...
# 380  8422_3150_ROBERT-ST,-SOUTH-CONWAY-ST_NA_NA_WES...
# 381  8420_3149_ROBERT-ST,-SOUTH-FAIRVIEW-ST_NA_NA_W...
# 382  8420_3149_ROBERT-ST,-SOUTH-FAIRVIEW-ST_NA_NA_W...
# 383  8420_3149_ROBERT-ST,-SOUTH-FAIRVIEW-ST_NA_NA_W...
# 384  7592_1128_D-ST,-DORCHESTER-AVE_NA_NA_SOUTH-BOS...
# 385  7592_1128_D-ST,-DORCHESTER-AVE_NA_NA_SOUTH-BOS...
# 386  7592_1128_D-ST,-DORCHESTER-AVE_NA_NA_SOUTH-BOS...
# 387  8409_1362_ELM-HILL-AVE,-HOWLAND-ST_NA_NA_ROXBU...
# 388  8409_1362_ELM-HILL-AVE,-HOWLAND-ST_NA_NA_ROXBU...
# 389  8409_1362_ELM-HILL-AVE,-HOWLAND-ST_NA_NA_ROXBU...
# 390  7292_173_DORCHESTER-ST,-OLD-COLONY-AVE_NA_NA_S...
# 391  7292_173_DORCHESTER-ST,-OLD-COLONY-AVE_NA_NA_S...
# 392  7292_173_DORCHESTER-ST,-OLD-COLONY-AVE_NA_NA_S...
# 393  8413_2158_RIVER-ST,-WALTER-ST,-WEBSTER-ST_NA_N...
# 394  8413_2158_RIVER-ST,-WALTER-ST,-WEBSTER-ST_NA_N...
# 395  8413_2158_RIVER-ST,-WALTER-ST,-WEBSTER-ST_NA_N...
#
# [396 rows x 9 columns]

# %%
all_data
# Out:
#              times   east  south   west  north  data_id
# 0      07:00-08:00  200.0    NaN  160.0    NaN        1
# 1      08:00-09:00  222.0    NaN  261.0    NaN        1
# 2      09:00-10:00  185.0    NaN  220.0    NaN        1
# 3      10:00-11:00  150.0    NaN  140.0    NaN        1
# 4      11:00-12:00  168.0    NaN  167.0    NaN        1
# 5      12:00-13:00  217.0    NaN  172.0    NaN        1
# 6      13:00-14:00  182.0    NaN  178.0    NaN        1
# 7      14:00-15:00  183.0    NaN  209.0    NaN        1
# 8      15:00-16:00  168.0    NaN  230.0    NaN        1
# 9      16:00-17:00  199.0    NaN  260.0    NaN        1
# 10     17:00-18:00  210.0    NaN  349.0    NaN        1
# 11     07:00-08:00   19.0   45.0   54.0   39.0        2
# 12     08:00-09:00   85.0   57.0   35.0   93.0        2
# 13     09:00-10:00   24.0   38.0   16.0   31.0        2
# 14     10:00-11:00    8.0   23.0   24.0   15.0        2
# 15     11:00-12:00    8.0   26.0    4.0   28.0        2
# 16     12:00-13:00   14.0   30.0   12.0   22.0        2
# 17     13:00-14:00   20.0   25.0   10.0   28.0        2
# 18     14:00-15:00    9.0   39.0   21.0   41.0        2
# 19     15:00-16:00   58.0   20.0   10.0   44.0        2
# 20     16:00-17:00   23.0   25.0   38.0   64.0        2
# 21     17:00-18:00   23.0   39.0   55.0   54.0        2
# 22     07:00-08:00    2.0    NaN    0.0    NaN        3
# 23     08:00-09:00    8.0    NaN    1.0    NaN        3
# 24     09:00-10:00    3.0    NaN    0.0    NaN        3
# 25     10:00-11:00    0.0    NaN    1.0    NaN        3
# 26     11:00-12:00    1.0    NaN    0.0    NaN        3
# 27     12:00-13:00    1.0    NaN    1.0    NaN        3
# 28     13:00-14:00    1.0    NaN    1.0    NaN        3
# 29     14:00-15:00    2.0    NaN    0.0    NaN        3
# ...            ...    ...    ...    ...    ...      ...
# 69749  10:00-11:00  310.0   83.0  415.0   31.0      394
# 69750  11:00-12:00  261.0   63.0  426.0   43.0      394
# 69751  12:00-13:00  276.0   31.0  385.0   33.0      394
# 69752  13:00-14:00  331.0   50.0  487.0   31.0      394
# 69753  14:00-15:00  351.0   69.0  457.0   42.0      394
# 69754  15:00-16:00  340.0   89.0  467.0   34.0      394
# 69755  16:00-17:00  378.0  114.0  516.0   60.0      394
# 69756  17:00-18:00  484.0  126.0  618.0   61.0      394
# 69757  07:00-08:00   24.0   15.0   22.0   17.0      395
# 69758  08:00-09:00    9.0   14.0    1.0   10.0      395
# 69759  09:00-10:00    7.0   12.0    4.0    7.0      395
# 69760  10:00-11:00   11.0    6.0   12.0    9.0      395
# 69761  11:00-12:00    6.0   13.0    5.0   18.0      395
# 69762  12:00-13:00    1.0    4.0    6.0    7.0      395
# 69763  13:00-14:00    0.0   10.0    2.0    1.0      395
# 69764  14:00-15:00    4.0   29.0    3.0   11.0      395
# 69765  15:00-16:00   12.0   31.0    9.0    9.0      395
# 69766  16:00-17:00    6.0   48.0    3.0   14.0      395
# 69767  17:00-18:00   21.0   40.0    7.0   17.0      395
# 69768  07:00-08:00    0.0    1.0    0.0    0.0      396
# 69769  08:00-09:00    0.0    0.0    0.0    0.0      396
# 69770  09:00-10:00    0.0    0.0    1.0    0.0      396
# 69771  10:00-11:00    0.0    0.0    0.0    0.0      396
# 69772  11:00-12:00    0.0    0.0    0.0    0.0      396
# 69773  12:00-13:00    3.0    1.0    0.0    0.0      396
# 69774  13:00-14:00    2.0    0.0    0.0    0.0      396
# 69775  14:00-15:00    1.0    0.0    1.0    0.0      396
# 69776  15:00-16:00    4.0    0.0    2.0    0.0      396
# 69777  16:00-17:00    4.0    0.0    2.0    0.0      396
# 69778  17:00-18:00    0.0    0.0    3.0    0.0      396
#
# [69779 rows x 6 columns]

# %%
data_info.filename.nunique()
# Out:
# 144

# %%
all_joined = pd.merge(left=all_data,right=data_info, left_on='data_id', right_on='id')

# %%
all_joined.groupby(['data_type']).sum()
# Out:
#                 east_x   south_x    west_x   north_x   data_id          id
# data_type
# all motors    257657.0  265758.0  295610.0  312225.0  12174719  12174719.0
# all peds hr.   59103.0   62762.0   57662.0   65817.0    300644    300644.0
# bicycles hr.    3491.0    3541.0    4781.0    4651.0    303217    303217.0

# %%
data_info.head()
# Out:
#     id                                          address           date  \
# 0  1.0  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500  Date -4.17.14
# 1  2.0  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500  Date -4.17.14
# 2  3.0  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500  Date -4.17.14
# 3  4.0  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500  Date - 4.9.14
# 4  5.0  Leo Sullivan 14 Dorr St. Roxbury, MA 02119 3500  Date - 4.9.14
#
#              east          south           west          north     data_type  \
# 0      Dudley St.     Hampden St    Dunmore St.      Dudley St    all motors
# 1      Dudley St.     Hampden St    Dunmore St.      Dudley St  all peds hr.
# 2      Dudley St.     Hampden St    Dunmore St.      Dudley St  bicycles hr.
# 3  No. Beacon St.  Cambridge St.  Brighton Ave.  Cambridge St.    all motors
# 4  No. Beacon St.  Cambridge St.  Brighton Ave.  Cambridge St.  all peds hr.
#
#                                             filename
# 0  6813_207_DUDLEY-ST,-HAMPDEN-ST_NA_NA_ROXBURY_1...
# 1  6813_207_DUDLEY-ST,-HAMPDEN-ST_NA_NA_ROXBURY_1...
# 2  6813_207_DUDLEY-ST,-HAMPDEN-ST_NA_NA_ROXBURY_1...
# 3  6817_186_BRIGHTON-AVE,-CAMBRIDGE-ST,-NORTH-BEA...
# 4  6817_186_BRIGHTON-AVE,-CAMBRIDGE-ST,-NORTH-BEA...
